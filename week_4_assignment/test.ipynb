# %%
print("hi")
# Out:
# hi

# %%
from utils import Utils

utils = Utils()
x="""
        Split content into word shingles of length up to n with optional overlap.

        Each shingle contains at most n consecutive words. Consecutive shingles
        share `overlap` words when overlap > 0. The final shingle may contain
        fewer than n words if the remaining text is shorter.
        """
n=5
shingles=utils.get_shingles(n,x,n-1)
print(shingles)
# Out:
# ['Split content into word shingles', 'content into word shingles of', 'into word shingles of length', 'word shingles of length up', 'shingles of length up to', 'of length up to n', 'length up to n with', 'up to n with optional', 'to n with optional overlap.', 'n with optional overlap. Each', 'with optional overlap. Each shingle', 'optional overlap. Each shingle contains', 'overlap. Each shingle contains at', 'Each shingle contains at most', 'shingle contains at most n', 'contains at most n consecutive', 'at most n consecutive words.', 'most n consecutive words. Consecutive', 'n consecutive words. Consecutive shingles', 'consecutive words. Consecutive shingles share', 'words. Consecutive shingles share `overlap`', 'Consecutive shingles share `overlap` words', 'shingles share `overlap` words when', 'share `overlap` words when overlap', '`overlap` words when overlap >', 'words when overlap > 0.', 'when overlap > 0. The', 'overlap > 0. The final', '> 0. The final shingle', '0. The final shingle may', 'The final shingle may contain', 'final shingle may contain fewer', 'shingle may contain fewer than', 'may contain fewer than n', 'contain fewer than n words', 'fewer than n words if', 'than n words if the', 'n words if the remaining', 'words if the remaining text', 'if the remaining text is', 'the remaining text is shorter.']

# %%
print(shingles[0])
hash_value=utils.hash(shingles[0])
print(hash_value)
# Out:
# Split content into word shingles
# 229494967682449041806493558430770716582
