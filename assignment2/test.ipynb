# %%
print("ji")
# Out:
# ji

# %%
s="Hey my name is Chandrahaas"
encoded_string=list(s.encode("utf-8"))
print(encoded_string)
print(len(s))
print(len(encoded_string))
# Out:
# [72, 101, 121, 32, 109, 121, 32, 110, 97, 109, 101, 32, 105, 115, 32, 67, 104, 97, 110, 100, 114, 97, 104, 97, 97, 115]
# 26
# 26

# %%
word="ఆంధ్రప్రదేశ్"
print(word.split())
list(word)
# Out:
# ['ఆంధ్రప్రదేశ్']
# ['ఆ', 'ం', 'ధ', '్', 'ర', 'ప', '్', 'ర', 'ద', 'ే', 'శ', '్']
